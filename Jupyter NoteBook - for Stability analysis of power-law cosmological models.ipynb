# %% [markdown]
# # Title:  Stability analysis of power-law cosmological models
#
# **Authors:**
# Jose Mathew, A. Thariq
#
# **Affiliations:**
# Department of Physics, The Cochin College
#
# **Abstract:**
# In this paper, we revisit the stability of power-law models, focusing on an alternative approach that differs significantly from the standard approaches used in studying power-law models. In the standard approach, stability is studied by reducing the system of background FRW equations to a one-dimensional system for a new background variable $X$ in terms of the number of e-foldings. However, we rewrote the equations, incorporating $H$ into the system and went on to do the calculations up to the second order.
# We demonstrate by computing the deviations from the power-law exact solution to second-order in time and show that power-law contraction is never an attractor in time, regardless of parameter values.  Our analysis shows that while first-order corrections align with existing interpretations, second-order corrections introduce significant deviations that cannot be explained by a simple time shift that explains the first-order diverging terms. We got that the scaling solutions to be saddle-like (metastable) when evolved in time. With importance, we note that in the number of e-folds, the system remains an attractor, while in cosmic time, it is unstable. We also support our claim with numerical results. This new insight has broader implications for the study of attractor behaviour of differential equation solutions and raises questions about the stability of scenarios like the ekpyrotic bounce driven by an exponential potential. Our work also hints that the different temporal variables we use might not be equivalent in all scenarios.
#
# ---
#
# ## Differential Equations Details
#
# We study the following system of differential equations:
#
# \[
# \begin{aligned}
# \frac{dx}{dt} &= -3 x (1 - x^2) H + \frac{\sqrt{6}}{2} \lambda (x^2 - 1) H, \\
# \frac{dH}{dt} &= -3 x^2 H^2,
# \end{aligned}
# \]
#
# where $\lambda = -\sqrt{7}$. The system is integrated over the time interval $[t_i, -C0]$ with various initial conditions.
# The preprint can be found at https://arxiv.org/abs/2410.18925

# %% [markdown]
# # Explicit Expressions for $x_1, H_1, x_2, H_2, x_3, H_3, x_4, H_4$
#
# \begin{align}
# x_1 &= 1.08012344973464337182766123935 +
# \left( 0.00736307692568681782489661403570 - 0.00354587096373813920957347951792 i \right)
# (C_0 + t)^{1/7} \nonumber \\
# &\quad + \left( 0.000707118253440925748205289238077 - 0.000886698243852244640983223158201 i \right)
# (C_0 + t)^{2/7} \nonumber \\
# &\quad + \frac{-0.000150161477983736521039350386585 + 0.0000723139565195930200792947221414 i}{(C_0 + t)^{6/7}}.
# \end{align}
#
# \begin{align}
# H_1 &= \frac{2}{-200 + 7t} +
# \frac{-0.00340844230698617058110358108494 + 0.00164141930471431862432272535247 i}{(C_0 + t)^{6/7}} \nonumber \\
# &\quad + \frac{0.0424703000347289486792928107458}{(C_0 + t)^2}
# + \frac{-0.000256076168620551271465627005930 + 0.000321109358870797957148111144884 i}{(C_0 + t)^{5/7}} \nonumber \\
# &\quad + \frac{-0.000417067543586690206757695337759 + 0.000200849143319752674271183126614 i}{(C_0 + t)^{13/7}}
# + \frac{0.00388888888888888888888888888889}{(C_0 + t)^3}.
# \end{align}
#
# \begin{align}
# x_2 &= 1.08012344973464337182766123935 +
# \left( -0.0138262276794143521774316943451 + 0.00665836032426006800774942727322 i \right) (C_0 + t)^{1/7} \nonumber \\
# &\quad + \left( 0.00110487227100144648157076443450 - 0.00138546600601913225153628618469 i \right) (C_0 + t)^{2/7} \nonumber \\
# &\quad + \frac{0.00000563105542439011953897563949692 - 0.00000271177336948473825297355208030 i}{(C_0 + t)^{6/7}}.
# \end{align}
#
# \begin{align}
# H_2 &= \frac{2}{-200 + 7t} +
# \frac{0.00640029974481670409830717773601 - 0.00308222190986402713241263127744 i}{(C_0 + t)^{6/7}} \nonumber \\
# &\quad + \frac{0.0136683978629803310730808808502}{(C_0 + t)^2}
# + \frac{-0.000400119013469611361665042196766 + 0.000501733373235621808043923663881 i}{(C_0 + t)^{5/7}} \nonumber \\
# &\quad + \frac{0.0000156400328845008827534135751660 - 0.00000753184287449072528516936724804 i}{(C_0 + t)^{13/7}}
# + \frac{0.00000350000000000000000000000000000}{(C_0 + t)^3}.
# \end{align}
#
# \begin{align}
# x_3 &= 1.08012344973464337182766123935 +
# \left( -0.0483219303324712223348650930043 + 0.0232706151799037847847994066696 i \right) (C_0 + t)^{1/7} \nonumber \\
# &\quad + \left( 0.00785686948267695275783654708975 - 0.00985220270946938489981359064668 i \right) (C_0 + t)^{2/7} \nonumber \\
# &\quad + \frac{-0.00150161477983736521039350386585 + 0.000723139565195930200792947221414 i}{(C_0 + t)^{6/7}}.
# \end{align}
#
# \begin{align}
# H_3 &= \frac{2}{-200 + 7t} +
# \frac{0.0223687071808053939403921352094 - 0.0107722016338135863043627422923 i}{(C_0 + t)^{6/7}} \nonumber \\
# &\quad + \frac{0.000260298313334468549684218528008}{(C_0 + t)^2}
# + \frac{-0.00284529076245056968295141117700 + 0.00356788176523108841275679049871 i}{(C_0 + t)^{5/7}} \nonumber \\
# &\quad + \frac{-0.00417067543586690206757695337759 + 0.00200849143319752674271183126614 i}{(C_0 + t)^{13/7}}
# + \frac{0.0350000000000000000000000000000}{(C_0 + t)^3}.
# \end{align}
#
# \begin{align}
# x_4 &= 1.08012344973464337182766123935 +
# \left( -0.131916025043060346440061623345 + 0.0635274094747161887565304366137 i \right) (C_0 + t)^{1/7} \nonumber \\
# &\quad + \left( 0.0314274779307078110313461883590 - 0.0394088108378775395992543625867 i \right) (C_0 + t)^{2/7} \nonumber \\
# &\quad + \frac{0.0300322955967473042078700773169 - 0.0144627913039186040158589444283 i}{(C_0 + t)^{6/7}}.
# \end{align}
#
# \begin{align}
# H_4 &= \frac{2}{-200 + 7t} +
# \frac{0.0610652537334822635775901226664 - 0.0294074762890867364553517247586 i}{(C_0 + t)^{6/7}} \nonumber \\
# &\quad + \frac{1.31472861985008207100774774389}{(C_0 + t)^2}
# + \frac{-0.0113811630498022787318056447080 + 0.0142715270609243536510271619948 i}{(C_0 + t)^{5/7}} \nonumber \\
# &\quad + \frac{0.0834135087173380413515390675519 - 0.0401698286639505348542366253229 i}{(C_0 + t)^{13/7}}
# + \frac{3.50000000000000000000000000000}{(C_0 + t)^3}.
# \end{align}
# **Where $C0=-28.57142857142857$**
# ## Note that these are analytic expressions for different initial conditions. Here we set $\Delta^{(2)} H =\Delta^{(2)}X=0$. Further $H_i= H_p +\Delta H$ and $X_i=X_p + \Delta X$

# %%
#Defining the solutions for the selected initial conditions
import numpy as np

def funcs(t, C0=-28.57142857142857):  # Reduced to reasonable precision
    base = (C0 + t).astype(complex)

    return (1.080123449734643*t/t,2 / (-200 + 7 * t),
        1.080123449734643 + 
        (0.00736307692568682 - 0.00354587096373814j) * base**(1/7) +
        (0.00070711825344093 - 0.00088669824385224j) * base**(2/7) +
        (-0.00015016147798374 + 0.00007231395651959j) / base**(6/7),
        
        2 / (-200 + 7 * t) +
        (-0.00340844230698617 + 0.00164141930471432j) / base**(6/7) +
        0.04247030003472895 / base**2 +
        (-0.00025607616862055 + 0.0003211093588708j) / base**(5/7) +
        (-0.00041706754358669 + 0.00020084914331975j) / base**(13/7) +
        0.00388888888888889 / base**3,
        
        1.080123449734643 + 
        (-0.01382622767941435 + 0.00665836032426007j) * base**(1/7) +
        (0.00110487227100145 - 0.00138546600601913j) * base**(2/7) +
        (0.00000563105542439 - 0.00000271177336948j) / base**(6/7),
        
        2 / (-200 + 7 * t) +
        (0.00640029974481670 - 0.00308222190986403j) / base**(6/7) +
        0.01366839786298033 / base**2 +
        (-0.00040011901346961 + 0.00050173337323562j) / base**(5/7) +
        (0.00001564003288450 - 0.00000753184287449j) / base**(13/7) +
        0.0000035 / base**3,
        
        1.080123449734643 + 
        (-0.04832193033247122 + 0.02327061517990378j) * base**(1/7) +
        (0.00785686948267695 - 0.00985220270946938j) * base**(2/7) +
        (-0.00150161477983737 + 0.00072313956519593j) / base**(6/7),
        
        2 / (-200 + 7 * t) +
        (0.02236870718080539 - 0.01077220163381359j) / base**(6/7) +
        0.00026029831333447 / base**2 +
        (-0.00284529076245057 + 0.00356788176523109j) / base**(5/7) +
        (-0.00417067543586690 + 0.00200849143319753j) / base**(13/7) +
        0.035 / base**3,
        
        1.080123449734643 + 
        (-0.13191602504306035 + 0.06352740947471619j) * base**(1/7) +
        (0.03142747793070781 - 0.03940881083787754j) * base**(2/7) +
        (0.03003229559674730 - 0.01446279130391860j) / base**(6/7),
        
        2 / (-200 + 7 * t) +
        (0.06106525373348226 - 0.02940747628908674j) / base**(6/7) +
        1.31472861985008 / base**2 +
        (-0.01138116304980228 + 0.01427152706092435j) / base**(5/7) +
        (0.08341350871733804 - 0.04016982866395053j) / base**(13/7) +
        3.5 / base**3
    )

# %%
#Phase portrait
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 50 decimal digits
getcontext().prec = 50

def ode_system(t, y, lambda_val):
    x, H = y
    dxdt = (-3 * x * (1 - x**2) + (np.sqrt(6)/2) * lambda_val * (x**2 - 1)) * H
    dHdt = -3 * x**2 * H**2
    return [dxdt, dHdt]

lambda_val = -np.sqrt(7)
C0temp = -200/7
t_span = (1, -C0temp-0.001)
t_eval = np.linspace(t_span[0], t_span[1], 500000)
tforini=np.linspace(1,1,1)
x0param, H0param, x1param, H1param, x2param, H2param, x3param, H3param,x4param,H4param = funcs(tforini)
initial_conditions = [
    [x0param[0],H0param[0]],
    [x1param[0],H1param[0]],
    #[x2param[0],H2param[0]],
    [x3param[0],H3param[0]],
    [x4param[0],H4param[0]]
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]

solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)

plt.figure(figsize=(8, 6))

# Define grid for streamplot
H_range = np.linspace(-1.0e4, -1.0e-5, 100)
x_range = np.linspace(initial_conditions[0][0] - 0.15, initial_conditions[0][0] + 0.1, 100)
H_grid, x_grid = np.meshgrid(H_range, x_range)

DX = (-3 * x_grid * (1 - x_grid**2) + (np.sqrt(6)/2) * lambda_val * (x_grid**2 - 1)) * H_grid
DH = -3 * x_grid**2 * H_grid**2

# Plot the streamlines in blue (with a lower zorder)
plt.streamplot(H_grid, x_grid, DH, DX, color='lightblue', density=2.0, arrowsize=1, zorder=1)

# Plot the solution curves in red (with a higher zorder so they appear on top)
colors = ['red', 'green', 'brown','violet','darkgray']

x0paramf, H0paramf, x1paramf, H1paramf, x2paramf, H2paramf, x3paramf, H3paramf,x4paramf,H4paramf = funcs(t_eval)
plt.plot(H0paramf, x0paramf, color='black', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x0param[0]):.5f}, H(0)={np.real(H0param[0]):.5f}')
plt.plot(H1paramf, x1paramf, color='purple', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x1param[0]):.5f}, H(0)={np.real(H1param[0]):.5f}')
plt.plot(H3paramf, x3paramf, color='orange', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x3param[0]):.5f}, H(0)={np.real(H3param[0]):.5f}')
plt.plot(H4paramf, x4paramf, color='blue', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x4param[0]):.5f}, H(0)={np.real(H4param[0]):.5f}')

for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(H_sol, x_sol, color=colors[i],  lw=2,linestyle='--', marker='o', markersize=3, markevery=100,label=f'IC: x(1)={np.real(sol.y[0,0]):.5f}, H(0)={np.real(sol.y[1,0]):.5f}')

plt.xlabel('$H(t)$ in $M_p$')
plt.ylabel('$X(t)$')
plt.title('Phase Portrait')
plt.xlim(-10000,-0.00001)
plt.ylim(x0param[0] - .15, x0param[0] + .1)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.tight_layout()
plt.xscale('symlog', linthresh=1e-3, linscale=1e-3)  # Reduce the linear region near zero
plt.grid(True)
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\phase_portrait2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
#The phaseportrait showing the regions for which Hubble parametr is positive alon
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 50 decimal digits
getcontext().prec = 50

def ode_system(t, y, lambda_val):
    x, H = y
    dxdt = (-3 * x * (1 - x**2) + (np.sqrt(6)/2) * lambda_val * (x**2 - 1)) * H
    dHdt = -3 * x**2 * H**2
    return [dxdt, dHdt]

lambda_val = -np.sqrt(7)
C0temp = -200/7
t_span = (1, -C0temp-0.001)
t_eval = np.linspace(t_span[0], t_span[1], 500000)
tforini=np.linspace(1,1,1)
x0param, H0param, x1param, H1param, x2param, H2param, x3param, H3param,x4param,H4param = funcs(tforini)
initial_conditions = [
    [x0param[0],H0param[0]],
    [x1param[0],H1param[0]],
    #[x2param[0],H2param[0]],
    [x3param[0],H3param[0]],
    [x4param[0],H4param[0]]
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]

solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)

plt.figure(figsize=(8, 6))

# Define grid for streamplot
#Hrangelog1=np.linspace(4,0,1000)
#Hrangelog2=np.linspace(0,2,1000)
#Hrange1=-10**Hrangelog1
#Hrange2=10**Hrangelog2
#H_range = np.concatenate((Hrange1, Hrange2))
H_range = np.linspace(-1.0e4, 100, 100)
x_range = np.linspace(initial_conditions[0][0] - 0.15, initial_conditions[0][0] + 0.1, 100)
H_grid, x_grid = np.meshgrid(H_range, x_range)

DX = (-3 * x_grid * (1 - x_grid**2) + (np.sqrt(6)/2) * lambda_val * (x_grid**2 - 1)) * H_grid
DH = -3 * x_grid**2 * H_grid**2

# Plot the streamlines in blue (with a lower zorder)
plt.streamplot(H_grid, x_grid, DH, DX, color='lightblue', density=2.0, arrowsize=1, zorder=1)

# Plot the solution curves in red (with a higher zorder so they appear on top)
colors = ['red', 'green', 'brown','violet','darkgray']

x0paramf, H0paramf, x1paramf, H1paramf, x2paramf, H2paramf, x3paramf, H3paramf,x4paramf,H4paramf = funcs(t_eval)
plt.plot(H0paramf, x0paramf, color='black', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x0param[0]):.5f}, H(0)={np.real(H0param[0]):.5f}, The scaling solution')
plt.plot(H1paramf, x1paramf, color='purple', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x1param[0]):.5f}, H(0)={np.real(H1param[0]):.5f}')
plt.plot(H3paramf, x3paramf, color='orange', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x3param[0]):.5f}, H(0)={np.real(H3param[0]):.5f}')
plt.plot(H4paramf, x4paramf, color='blue', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x4param[0]):.5f}, H(0)={np.real(H4param[0]):.5f}')

for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(H_sol, x_sol, color=colors[i],  lw=2,linestyle='--', marker='o', markersize=3, markevery=100,label=f'IC: x(1)={np.real(sol.y[0,0]):.5f}, H(0)={np.real(sol.y[1,0]):.5f}')

plt.xlabel('$H(t)$ in $M_p$')
plt.ylabel('$X(t)$')
plt.title('Phase Portrait')
plt.xlim(-10000,100)
plt.xscale('symlog', linthresh=1e-3, linscale=1e-3)  # Reduce the linear region near zero
plt.ylim(x0param[0] - .15, x0param[0] + .1)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.tight_layout()
plt.xscale('symlog', linthresh=1e-3, linscale=1e-3)  # Reduce the linear region near zero
plt.grid(True)
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\phase_portrait1.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
tforini=np.linspace(1,1,1)
lambda_val = -np.sqrt(7)
C0temp = -200/7
t_span = (1, -C0temp-0.001)
t_eval = np.linspace(t_span[0], t_span[1], 500000)
tforini=np.linspace(1,1,1)
x0param, H0param, x1param, H1param, x2param, H2param, x3param, H3param,x4param,H4param = funcs(tforini)
initial_conditions = [
    [x0param[0],H0param[0]],
    [x1param[0],H1param[0]],
    #[x2param[0],H2param[0]],
    [x3param[0],H3param[0]],
    [x4param[0],H4param[0]]
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]
solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)
    colors = ['red', 'green', 'brown','violet','darkgray']

x0paramf, H0paramf, x1paramf, H1paramf, x2paramf, H2paramf, x3paramf, H3paramf,x4paramf,H4paramf = funcs(t_eval)
plt.plot(t_eval, x0paramf, color='black', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x0param[0]):.5f}, H(0)={np.real(H0param[0]):.5f}')
plt.plot(t_eval, x1paramf, color='purple', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x1param[0]):.5f}, H(0)={np.real(H1param[0]):.5f}')
plt.plot(t_eval, x3paramf, color='orange', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x3param[0]):.5f}, H(0)={np.real(H3param[0]):.5f}')
plt.plot(t_eval, x4paramf, color='blue', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x4param[0]):.5f}, H(0)={np.real(H4param[0]):.5f}')

for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(t_eval[0:400000], x_sol[0:400000], color=colors[i],  lw=2,linestyle=':', marker='o', markersize=3, markevery=10000,label=f'IC: x(1)={np.real(sol.y[0,0]):.5f}, H(0)={np.real(sol.y[1,0]):.5f}')
plt.ylim(0.8,1.2)
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('X(t)')
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.tight_layout()
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\Xvstnew.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
tforini=np.linspace(1,1,1)
lambda_val = -np.sqrt(7)
C0temp = -200/7
t_span = (1, -C0temp-0.001)
t_eval = np.linspace(t_span[0], t_span[1], 500000)
tforini=np.linspace(1,1,1)
x0param, H0param, x1param, H1param, x2param, H2param, x3param, H3param,x4param,H4param = funcs(tforini)
initial_conditions = [
    [x0param[0],H0param[0]],
    [x1param[0],H1param[0]],
    #[x2param[0],H2param[0]],
    [x3param[0],H3param[0]],
    [x4param[0],H4param[0]]
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]
solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)
    colors = ['red', 'green', 'brown','violet','darkgray']

x0paramf, H0paramf, x1paramf, H1paramf, x2paramf, H2paramf, x3paramf, H3paramf,x4paramf,H4paramf = funcs(t_eval)
plt.plot(t_eval, H0paramf, color='black', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x0param[0]):.5f}, H(0)={np.real(H0param[0]):.5f}')
plt.plot(t_eval, H1paramf, color='purple', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x1param[0]):.5f}, H(0)={np.real(H1param[0]):.5f}')
plt.plot(t_eval, H3paramf, color='orange', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x3param[0]):.5f}, H(0)={np.real(H3param[0]):.5f}')
plt.plot(t_eval, H4paramf, color='blue', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x4param[0]):.5f}, H(0)={np.real(H4param[0]):.5f}')

for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(t_eval[0:400000], H_sol[0:400000], color=colors[i],  lw=3,linestyle=':', marker='o', markersize=4, markevery=10000,label=f'IC: x(1)={np.real(sol.y[0,0]):.5f}, H(0)={np.real(sol.y[1,0]):.5f}')
plt.ylim(-.05,0)
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('H(t)')
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.tight_layout()
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\Hvstnew.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
tforini=np.linspace(1,1,1)
lambda_val = -np.sqrt(7)
C0temp = -200/7
t_span = (1, -C0temp-0.001)
t_eval = np.linspace(t_span[0], t_span[1], 500000)
tforini=np.linspace(1,1,1)
x0param, H0param, x1param, H1param, x2param, H2param, x3param, H3param,x4param,H4param = funcs(tforini)
initial_conditions = [
    [x0param[0],H0param[0]],
    [x1param[0],H1param[0]],
    #[x2param[0],H2param[0]],
    [x3param[0],H3param[0]],
    [x4param[0],H4param[0]]
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]

solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)
    colors = ['red', 'green', 'brown','violet','darkgray']

x0paramf, H0paramf, x1paramf, H1paramf, x2paramf, H2paramf, x3paramf, H3paramf,x4paramf,H4paramf = funcs(t_eval)
plt.plot(t_eval, H0paramf, color='black', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x0param[0]):.5f}, H(0)={np.real(H0param[0]):.5f}')
plt.plot(t_eval, H1paramf, color='purple', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x1param[0]):.5f}, H(0)={np.real(H1param[0]):.5f}')
plt.plot(t_eval, H3paramf, color='orange', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x3param[0]):.5f}, H(0)={np.real(H3param[0]):.5f}')
plt.plot(t_eval, H4paramf, color='blue', lw=2, linestyle='solid',marker='o', markersize=0,  markevery=60,zorder=20,label=f'IC: x(1)={np.real(x4param[0]):.5f}, H(0)={np.real(H4param[0]):.5f}')

for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(t_eval[0:400000], H_sol[0:400000], color=colors[i],  lw=3,linestyle=':', marker='o', markersize=4, markevery=10000,label=f'IC: x(1)={np.real(sol.y[0,0]):.5f}, H(0)={np.real(sol.y[1,0]):.5f}')
plt.ylim(-1000,0)
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('H(t)')
plt.yscale('symlog', linthresh=1e-3)  # Reduce the linear region near zero
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.tight_layout()
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\Hvstfullnew.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Below is a random phase portrait

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 50 decimal digits
getcontext().prec = 50

def ode_system(t, y, lambda_val):
    x, H = y
    dxdt = (-3 * x * (1 - x**2) + (np.sqrt(6)/2) * lambda_val * (x**2 - 1)) * H
    dHdt = -3 * x**2 * H**2
    return [dxdt, dHdt]

lambda_val = -np.sqrt(7)
C0temp = -3000
t_span = (1, -C0temp)
t_eval = np.linspace(t_span[0], t_span[1], 500000)

initial_conditions = [
    [1.08, -0.01],
    [1.18, -0.01],
    [.98, -0.01],
    #[1.08012344973464337182766123934799944295086738450972442495189239963493622964,-0.00100351229302558956347215253386853988961364776718514]
]

solutions = []
for ic in initial_conditions:
    sol = solve_ivp(
        ode_system,
        t_span,
        ic,
        args=(lambda_val,),
        t_eval=t_eval,
        method='RK45',
        #atol=1e-22,   # Absolute tolerance
        #rtol=1e-22    # Relative tolerance
    )
    solutions.append(sol)

plt.figure(figsize=(8, 6))

# Define grid for streamplot
H_range = np.linspace(-1, -0.0001, 20)
x_range = np.linspace(initial_conditions[0][0] - 0.2, initial_conditions[0][0] + 0.2, 20)
H_grid, x_grid = np.meshgrid(H_range, x_range)

DX = (-3 * x_grid * (1 - x_grid**2) + (np.sqrt(6)/2) * lambda_val * (x_grid**2 - 1)) * H_grid
DH = -3 * x_grid**2 * H_grid**2

# Plot the streamlines in blue (with a lower zorder)
plt.streamplot(H_grid, x_grid, DH, DX, color='lightblue', density=0.75, arrowsize=2, zorder=1)

# Plot the solution curves in red (with a higher zorder so they appear on top)
colors = ['red', 'green', 'brown','violet']
for i, sol in enumerate(solutions):
    x_sol = sol.y[0]
    H_sol = sol.y[1]
    plt.plot(H_sol, x_sol, color=colors[i],  lw=3, marker='o', markevery=5,markersize=5, label=f'IC: x(1)={sol.y[0,0]:.2f}, H(0)={sol.y[1,0]:.3f}')

plt.xlabel('$H(t)$ in $M_p$')
plt.ylabel('$X(t)$')
plt.title('Phase Portrait')
plt.xlim(-1,-0.001)
plt.ylim(initial_conditions[0][0] - 0.2, initial_conditions[0][0] + 0.2)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=3)
plt.tight_layout()
#plt.xscale('symlog')
plt.grid(True)
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\phase_portrait.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 20 decimal digits
getcontext().prec = 30
C0temp = -200/7
t_vals = np.linspace(1, -C0temp-0.01, 20000)
# Example usage:
# You can pass a scalar t or a numpy array of t-values.
t_val = 0.0  # example scalar value
x0param, H0param, x1param, H1param, x2param,H2param, x3param, H3param,x4param,H4param = funcs(t_vals)
plt.plot(H0param,x0param,color='red')
plt.plot(H4param,x4param,linestyle='dashed',color='blue')
plt.plot(H1param,x1param,linestyle='dashed',color='green')
plt.plot(H3param,x3param,linestyle='dashed',color='orange')
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('X(t)')
plt.grid(True)
plt.xscale('symlog', linthresh=1e-3, linscale=1e-3)  # Reduce the linear region near zero
plt.xlim(-1000,0)
plt.ylim(.9,1.1)
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\XvsHold.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 20 decimal digits
getcontext().prec = 30
C0temp = -200/7
t_vals = np.linspace(1, -C0temp-0.0001, 200)



# Example usage:
# You can pass a scalar t or a numpy array of t-values.
t_val = 0.0  # example scalar value
x0param, H0param, x1param, H1param, x2param,H2param,x3param, H3param,x4param,H4param = funcs(t_vals)
plt.plot(t_vals,np.real(x0param),color='red')
plt.plot(t_vals,np.real(x1param),linestyle='dashed',color='blue')
#plt.plot(t_vals,np.real(x2param,linestyle='dashed',color='green')
plt.plot(t_vals,np.real(x3param),linestyle=':',color='teal')
plt.plot(t_vals,np.real(x4param),linestyle='--',color='brown')
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('X(t)')
plt.grid(True)
#plt.xlim(1,100)
plt.ylim(0.9,1.2)
#plt.xscale('symlog')
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\Xvstold.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from decimal import Decimal, getcontext

# Set precision to 20 decimal digits
getcontext().prec = 30
C0temp = -200/7
t_vals = np.linspace(1, -C0temp-0.0001, 200)



# Example usage:
# You can pass a scalar t or a numpy array of t-values.
t_val = 0.0  # example scalar value
x0param, H0param, x1param, H1param, x2param,H2param,x3param, H3param,x4param,H4param = funcs(t_vals)
plt.plot(t_vals,np.real(H0param),color='red')
plt.plot(t_vals,np.real(H1param),linestyle='dashed',color='blue')
#plt.plot(t_vals,np.real(x2param,linestyle='dashed',color='green')
plt.plot(t_vals,np.real(H3param),linestyle=':',color='teal')
plt.plot(t_vals,np.real(H4param),linestyle='--',color='brown')
plt.xlabel(r'Time in $1/M_p$')
plt.ylabel('H(t)')
plt.grid(True)
#plt.xlim(1,100)
#plt.ylim(0.9,1.2)
#plt.xscale('symlog')
plt.savefig(r'C:\Users\josec\Dropbox\Power_law_Inflation\figs\Xvstold.png', dpi=300, bbox_inches='tight')
plt.show()
